# %% [markdown]
# ## Data input and cleanup
#
# Data were collected into a table with the columns `well`, `rate`, and `mutant` using Google Docs and exported to CSV, which is the input file here.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas
from sklearn.linear_model import LinearRegression
from scipy.optimize import curve_fit 
from numpy import log, exp, linspace, sqrt, diag, array, nan
from numpy import concatenate

# %%
df = pandas.read_csv( 'raw_data.csv', index_col='mutant' )
raw_len = len( df )

df.drop( ['WT', 'WT1'], inplace=True )
df.dropna( inplace=True ) 

with open( '../../reference/allowed_mutants.txt' ) as fn:
    mutants = [ i.split('.')[0].upper() for i in fn.readlines() if len( i ) > 1 ]
    
def is_good( name ):
    return name in mutants 

not_allowed = []
l = []
for name in df.index:
    if is_good( name ) or name == 'BglB':
        l.append( name )
    else:
        new = name[0] + str( int( name[1:-1] ) - 3 ) + name[-1]
        #print 'suspected off by three', name,  
        if is_good( new ):
            l.append( new )
            #print 'fixed' 
        else:
            l.append( 'drop_me' )
            not_allowed.append( name )
            #print ', cannot fix' 
            
df.index = df['mutant'] = l
df.drop( ['drop_me'], inplace=True )

# temperature keys as CSV files in data/
temp_key = pandas.read_csv( '../../reference/temperature_key.csv' )
temp_key.index = temp_key.Well
df['temp'] = df.well.str[0].map( temp_key.Celsius.to_dict() ) 
df.dropna( inplace=True )
pos_and_neg = len( df )

# diagnostics 
print 'Input has {} rates. {} will be used, {} will be dropped because of mutant name, {} because negative).'.format( raw_len, len( df ), raw_len - pos_and_neg , pos_and_neg - len( df ) ), 
print 'Samples {} were dropped because the given native residue does not match the BglB sequence and is not off by three'.format( set( not_allowed ) )

df.to_csv( 'assay_data.csv' )
# Out:
# Input has 2951 rates. 2951 will be used, 0 will be dropped because of mutant name, 0 because negative). Samples set([]) were dropped because the given native residue does not match the BglB sequence and is not off by three

# %%
# define logistic equation 
def f(x, x0, k): 
    return 1/(1+exp(-k*(x-x0)))

empty = array( [ nan ] * 4 ) 
# util function to fit a mutant 
def fit( df ):
  
    name = df.mutant.unique()[0]
    mean_highest_rates = df[ df.rate > df.rate.quantile() ].rate.mean() or 1  
    #print 'mean of highest rates', mean_highest_rates
    #print 'max rate', df.rate.max()
    #df.rate = df.rate / df.rate.max()
    df.rate = df.rate / mean_highest_rates
    
    # linear fit gets us sensible starting params for the logistic fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]
    
    my_index = ['tm', 'k', 'err_tm', 'err_k' ]
    # try fitting to logistic eqn using approximate params from linear fit
    try:
        p0 = ( df.temp.mean(), slope )
        popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
        perr = sqrt( diag( pcov ) ) 
        
        # error checking 
        
        my_params = concatenate( [ popt, perr ] ) 
        if 20 < popt[0] < 60 and popt[1] < 0 and perr[0] < 1: 
            # biological assay limits, and make sure k is the right sign
            return pandas.Series( my_params, index=my_index ) 
        else:
            return pandas.Series( empty, index=my_index )
    except Exception as e:
        print name, e 
        return pandas.Series( empty, index=my_index )
    # done with error checking

# %%
# apply the function to the data set 
grouped = df.groupby( by='mutant' )
est = grouped.apply( fit )

print 'Tm estimated for {} of {} samples'.format( len( est.dropna() ), len( grouped ) )
# Out:
# mean of highest rates 0.142833333333
# max rate 0.182
# mean of highest rates 1.0
# max rate 1.27421236873
# mean of highest rates 0.407541666667
# max rate 0.455
# mean of highest rates 0.0908583333333
# max rate 0.112
# mean of highest rates 0.0061625
# max rate 0.00781
# mean of highest rates 2.3e-05
# max rate 0.0001
# mean of highest rates 0.02285
# max rate 0.0294
# mean of highest rates 7.7325e-05
# max rate 0.000158
# mean of highest rates 0.000131666666667
# max rate 0.00021
# mean of highest rates 0.00022285
# max rate 0.00319
# mean of highest rates 0.144641666667
# max rate 0.198
# mean of highest rates 0.00354916666667
# max rate 0.00526
# mean of highest rates 0.00824916666667
# max rate 0.0103
# mean of highest rates 0.005205
# max rate 0.00752
# mean of highest rates 0.0026175
# max rate 0.00487
# mean of highest rates 0.176533333333
# max rate 0.231
# mean of highest rates 0.134333333333
# max rate 0.175
# mean of highest rates 0.00025775
# max rate 0.000302
# mean of highest rates 0.000126916666667
# max rate 0.000184
# mean of highest rates 8.18416666667e-06
# max rate 5.43e-05
# mean of highest rates 0.32345
# max rate 0.388
# mean of highest rates 0.00069975
# max rate 0.000757
# mean of highest rates 0.42575
# max rate 0.468
# mean of highest rates 0.00055925
# max rate 0.00132
# mean of highest rates -1.075e-06
# max rate 0.000107
# mean of highest rates 0.0137108333333
# max rate 0.0181
# mean of highest rates 2.085e-05
# max rate 9.88e-05
# mean of highest rates 0.514
# max rate 0.57
# mean of highest rates 0.000385
# max rate 0.000423
# mean of highest rates 7.95833333333e-05
# max rate 0.000265
# mean of highest rates 0.000135
# max rate 0.00034
# mean of highest rates 0.0170883333333
# max rate 0.0375
# mean of highest rates 4.27545454545e-05
# max rate 9.45e-05
# mean of highest rates 0.021875
# max rate 0.0432
# mean of highest rates 6.88333333333e-06
# max rate 0.000111
# mean of highest rates 0.142833333333
# max rate 0.182
# mean of highest rates 1.83333333333e-05
# max rate 0.00013
# mean of highest rates 0.000303636363636
# max rate 0.00094
# mean of highest rates 0.0409833333333
# max rate 0.0532
# mean of highest rates 0.000185075
# max rate 0.000284
# mean of highest rates 0.00720666666667
# max rate 0.0104
# mean of highest rates 0.0247083333333
# max rate 0.0318
# mean of highest rates 0.329083333333
# max rate 0.343
# mean of highest rates 0.113991666667
# max rate 0.157
# mean of highest rates 0.02285
# max rate 0.0294
# mean of highest rates 0.318666666667
# max rate 0.368
# mean of highest rates 0.000317
# max rate 0.00054
# M261D Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# mean of highest rates 0.00125
# max rate 0.00182
# mean of highest rates 3.55666666667e-05
# max rate 4.91e-05
# mean of highest rates 0.2395
# max rate 0.273
# mean of highest rates 0.000267333333333
# max rate 0.000319
# mean of highest rates 0.0003195
# max rate 0.000458
# mean of highest rates 0.0040075
# max rate 0.00525
# mean of highest rates 0.07445
# max rate 0.0929
# mean of highest rates 0.036175
# max rate 0.0399
# mean of highest rates 0.000684
# max rate 0.000881
# mean of highest rates 0.004365
# max rate 0.0054
# mean of highest rates 0.16075
# max rate 0.178
# mean of highest rates 4.95636363636e-06
# max rate 5.94e-06
# mean of highest rates 0.00848
# max rate 0.0109
# mean of highest rates 3.96083333333e-05
# max rate 7.58e-05
# mean of highest rates 0.000245990909091
# max rate 0.000982
# mean of highest rates 0.000175
# max rate 0.00021
# mean of highest rates 0.000662083333333
# max rate 0.000692
# mean of highest rates 0.035025
# max rate 0.0394
# mean of highest rates 4.77e-05
# max rate 0.000379
# mean of highest rates 4.725e-06
# max rate 5.94e-06
# mean of highest rates 8.37416666667e-05
# max rate 0.000102
# mean of highest rates 0.0175175
# max rate 0.0269
# mean of highest rates 0.01256125
# max rate 0.02
# mean of highest rates 0.0734916666667
# max rate 0.0814
# mean of highest rates -3.44916666667e-05
# max rate 8.85e-05
# mean of highest rates 9.38666666667e-05
# max rate 0.000386
# mean of highest rates 0.299083333333
# max rate 0.343
# mean of highest rates 0.000183416666667
# max rate 0.000244
# mean of highest rates 0.135166666667
# max rate 0.155
# mean of highest rates 0.0119775
# max rate 0.0257
# mean of highest rates 1.06166666667e-05
# max rate 7.52e-05
# mean of highest rates 0.17575
# max rate 0.192
# mean of highest rates 0.0026675
# max rate 0.00308
# mean of highest rates 0.164166666667
# max rate 0.187
# mean of highest rates 0.0396666666667
# max rate 0.0507
# mean of highest rates 0.00507916666667
# max rate 0.00594
# mean of highest rates 0.124975
# max rate 0.159
# mean of highest rates 0.0011325
# max rate 0.0015
# mean of highest rates 0.274666666667
# max rate 0.297
# mean of highest rates 2.405e-05
# max rate 3.26e-05
# mean of highest rates 0.056945
# max rate 0.072
# mean of highest rates 0.38875
# max rate 0.454
# mean of highest rates 2.47333333333e-05
# max rate 3.4e-05
# mean of highest rates 0.00241166666667
# max rate 0.00282
# mean of highest rates 0.0017575
# max rate 0.00205
# mean of highest rates 0.0002975
# max rate 0.000358
# mean of highest rates 0.0151166666667
# max rate 0.0182
# mean of highest rates -4.38083333333e-05
# max rate 0.00017
# mean of highest rates 7.27166666667e-05
# max rate 0.000125
# mean of highest rates 0.00305691666667
# max rate 0.0072
# mean of highest rates 0.000558416666667
# max rate 0.000633
# mean of highest rates 2.74666666667e-05
# max rate 7.94e-05
# mean of highest rates -7.86666666667e-06
# max rate 5.52e-05
# mean of highest rates 0.000206520833333
# max rate 0.000275
# mean of highest rates 0.000121591666667
# max rate 0.000287
# mean of highest rates 0.000191863636364
# max rate 0.00113
# W399R Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# mean of highest rates 0.000201375
# max rate 0.00027
# mean of highest rates 0.000171666666667
# max rate 0.00047
# mean of highest rates 0.000256833333333
# max rate 0.000596
# mean of highest rates 9.78333333333e-06
# max rate 0.00018
# mean of highest rates 4.28458333333e-05
# max rate 0.000169
# W407R Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# mean of highest rates 0.04685
# max rate 0.07
# mean of highest rates 1.83333333333e-05
# max rate 0.00013
# mean of highest rates 0.00897833333333
# max rate 0.0131
# mean of highest rates 0.0159833333333
# max rate 0.0192
# mean of highest rates 0.20275
# max rate 0.372
# mean of highest rates 9.22181818182e-05
# max rate 0.000164
# mean of highest rates 0.000148866666667
# max rate 0.000322
# Tm estimated for 57 of 114 samples

# %%
print est.round( 2 )
# Out:
#            tm     k  err_tm  err_k
# mutant
# A192S   39.54 -1.92    0.45   0.87
# BglB    40.24 -1.45    0.09   0.09
# C167A     NaN   NaN     NaN    NaN
# C167Q   39.50 -0.99    0.22   0.17
# D403A     NaN   NaN     NaN    NaN
# E154D   39.45 -1.21    0.34   0.38
# E164A     NaN   NaN     NaN    NaN
# E164G     NaN   NaN     NaN    NaN
# E164R     NaN   NaN     NaN    NaN
# E177A   38.91 -1.11    0.34   0.53
# E177K   38.05 -1.28    0.55   0.94
# E177L   40.36 -1.46    0.41   0.48
# E222A   38.09 -1.22    0.46   0.75
# E222H     NaN   NaN     NaN    NaN
# E222K   39.90 -1.16    0.41   0.34
# E222Q   40.31 -1.49    0.26   0.30
# E222R   39.53 -1.01    0.30   0.23
# E222Y     NaN   NaN     NaN    NaN
# E353A     NaN   NaN     NaN    NaN
# E406A     NaN   NaN     NaN    NaN
# E406D   40.86 -1.34    0.28   0.49
# E426S   39.68 -1.67    0.13   0.18
# F415A     NaN   NaN     NaN    NaN
# F415N     NaN   NaN     NaN    NaN
# F72H    40.15 -0.84    0.36   0.20
# G355A     NaN   NaN     NaN    NaN
# H101R   40.41 -1.17    0.10   0.09
# H119A   40.51 -1.35    0.20   0.24
# H119E     NaN   NaN     NaN    NaN
# H119N     NaN   NaN     NaN    NaN
# ...       ...   ...     ...    ...
# T218A   40.33 -1.35    0.09   0.10
# T296A     NaN   NaN     NaN    NaN
# T352A     NaN   NaN     NaN    NaN
# V52G    39.54 -1.45    0.17   0.23
# W120A     NaN   NaN     NaN    NaN
# W120F   42.34 -0.74    0.27   0.13
# W120H   40.62 -0.87    0.15   0.09
# W325A   40.78 -0.83    0.44   0.27
# W325C   39.66 -1.30    0.18   0.19
# W325G     NaN   NaN     NaN    NaN
# W325H     NaN   NaN     NaN    NaN
# W325L     NaN   NaN     NaN    NaN
# W325R   40.35 -0.99    0.17   0.12
# W34A      NaN   NaN     NaN    NaN
# W399A     NaN   NaN     NaN    NaN
# W399C     NaN   NaN     NaN    NaN
# W399G     NaN   NaN     NaN    NaN
# W399R     NaN   NaN     NaN    NaN
# W399S     NaN   NaN     NaN    NaN
# W407A     NaN   NaN     NaN    NaN
# W407G     NaN   NaN     NaN    NaN
# W407Q     NaN   NaN     NaN    NaN
# W407R     NaN   NaN     NaN    NaN
# W409Y   38.80 -0.71    0.52   0.25
# Y166P     NaN   NaN     NaN    NaN
# Y18A    39.49 -0.84    0.33   0.19
# Y294A   40.81 -1.55    0.19   0.41
# Y294F   40.77 -1.17    1.00   1.21
# Y295A     NaN   NaN     NaN    NaN
# Y295G     NaN   NaN     NaN    NaN
#
# [114 rows x 4 columns]

# %%
# I looked at all the plots 

zero_list = [ 
    'E353A', 'H315E', 'M261D', 'P329N', 
    'Q313R', 'R76A', 'S16A', 'S16N', 
    'W325H', 'W325L', 'W407G', 'Y294F', 
]

for zero in zero_list:
    est.loc[ zero ] = empty

# %%
for index, dat in grouped:
    
    dat = dat[ ( dat.rate > 0 ) ] 
    rate = dat.rate / dat.rate.max() 
    my_params = est.loc[ index ]
    
    if my_params.tm:
            
        plt.figure( figsize=(4,3) )
        plt.scatter( dat.temp, rate, color='k', lw=0, marker='.', label=index )
        x = linspace( dat.temp.min(), dat.temp.max(), 50 )
        plt.plot( x, f( x, *my_params[0:2] ), color='purple', label='est. params' )
        #plt.plot( x, f( x, 39.9, -.7 ), color='green', label='BglB' )
        plt.xlabel( 'T (C)' )
        plt.ylabel( 'Normalized rate')
        plt.xticks( [ 30, 40, 50 ] )
        plt.yticks( [ 0, 0.25, .5, 0.75, 1 ] )
        plt.legend( loc='lower left' )
        plt.tight_layout()
        plt.savefig( 'plots/%s.pdf' % index, format='pdf' )
        plt.close()
# Out:
# tm        39.541484
# k         -1.917727
# err_tm     0.453912
# err_k      0.872830
# Name: A192S, dtype: float64
# tm        40.242588
# k         -1.452577
# err_tm     0.086724
# err_k      0.093796
# Name: BglB, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: C167A, dtype: float64
# tm        39.497344
# k         -0.986042
# err_tm     0.220236
# err_k      0.169818
# Name: C167Q, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: D403A, dtype: float64
# tm        39.447051
# k         -1.211123
# err_tm     0.344618
# err_k      0.384009
# Name: E154D, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E164A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E164G, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E164R, dtype: float64
# tm        38.908691
# k         -1.110711
# err_tm     0.341797
# err_k      0.531367
# Name: E177A, dtype: float64
# tm        38.049692
# k         -1.280071
# err_tm     0.549593
# err_k      0.943293
# Name: E177K, dtype: float64
# tm        40.360548
# k         -1.458962
# err_tm     0.407989
# err_k      0.479681
# Name: E177L, dtype: float64
# tm        38.086321
# k         -1.222088
# err_tm     0.464023
# err_k      0.750902
# Name: E222A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E222H, dtype: float64
# tm        39.899875
# k         -1.164380
# err_tm     0.409533
# err_k      0.335612
# Name: E222K, dtype: float64
# tm        40.311071
# k         -1.491056
# err_tm     0.255043
# err_k      0.296724
# Name: E222Q, dtype: float64
# tm        39.525517
# k         -1.010016
# err_tm     0.295745
# err_k      0.233692
# Name: E222R, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E222Y, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E353A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: E406A, dtype: float64
# tm        40.856135
# k         -1.335792
# err_tm     0.279643
# err_k      0.493449
# Name: E406D, dtype: float64
# tm        39.681507
# k         -1.665976
# err_tm     0.129835
# err_k      0.180872
# Name: E426S, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: F415A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: F415N, dtype: float64
# tm        40.151318
# k         -0.842982
# err_tm     0.355940
# err_k      0.195635
# Name: F72H, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: G355A, dtype: float64
# tm        40.411199
# k         -1.168924
# err_tm     0.103080
# err_k      0.094493
# Name: H101R, dtype: float64
# tm        40.508019
# k         -1.352267
# err_tm     0.197690
# err_k      0.238620
# Name: H119A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H119E, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H119N, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H178A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H178R, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H315E, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H315N, dtype: float64
# tm        39.541483
# k         -1.917728
# err_tm     0.453912
# err_k      0.872830
# Name: H373R, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H379R, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: H379T, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: I244E, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: I244N, dtype: float64
# tm        40.034378
# k         -0.956939
# err_tm     0.442616
# err_k      0.286003
# Name: I300N, dtype: float64
# tm        40.584870
# k         -0.868320
# err_tm     0.262930
# err_k      0.165482
# Name: I91E, dtype: float64
# tm        40.169177
# k         -1.919363
# err_tm     0.066040
# err_k      0.092774
# Name: K341A, dtype: float64
# tm        39.625295
# k         -1.769858
# err_tm     0.662038
# err_k      1.050098
# Name: L171A, dtype: float64
# tm        39.447051
# k         -1.211123
# err_tm     0.344618
# err_k      0.384009
# Name: L171R, dtype: float64
# tm        40.540905
# k         -0.952240
# err_tm     0.162704
# err_k      0.117835
# Name: L362M, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: M261D, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: M323A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: M323K, dtype: float64
# tm        39.817957
# k         -1.804258
# err_tm     0.177955
# err_k      0.243312
# Name: M358T, dtype: float64
# tm        41.838275
# k         -0.709281
# err_tm     0.241840
# err_k      0.111223
# Name: N163A, dtype: float64
# tm        39.862127
# k         -0.509579
# err_tm     0.639343
# err_k      0.145725
# Name: N163C, dtype: float64
# tm        39.619246
# k         -1.221021
# err_tm     0.275277
# err_k      0.270964
# Name: N163D, dtype: float64
# tm        39.347183
# k         -1.366240
# err_tm     0.233616
# err_k      0.352593
# Name: N220A, dtype: float64
# tm        41.938334
# k         -1.968411
# err_tm     0.282756
# err_k      1.111291
# Name: N220G, dtype: float64
# tm        40.292012
# k         -1.295127
# err_tm     0.401279
# err_k      0.390807
# Name: N220H, dtype: float64
# tm        40.213806
# k         -1.011732
# err_tm     0.286157
# err_k      0.201856
# Name: N220R, dtype: float64
# tm        42.332052
# k         -0.446682
# err_tm     0.239423
# err_k      0.042300
# Name: N220Y, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: N293A, dtype: float64
# tm        39.655382
# k         -1.422183
# err_tm     0.332553
# err_k      0.389115
# Name: N293C, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: N293D, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: N293Q, dtype: float64
# tm        41.221253
# k         -0.869138
# err_tm     0.311394
# err_k      0.242461
# Name: N354A, dtype: float64
# tm        41.929558
# k         -1.524158
# err_tm     0.136192
# err_k      0.372308
# Name: N404A, dtype: float64
# tm        42.963306
# k         -1.654853
# err_tm     0.186187
# err_k      0.218915
# Name: N404C, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: P329N, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: Q19A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: Q19C, dtype: float64
# tm        38.235654
# k         -0.937169
# err_tm     0.484026
# err_k      0.444247
# Name: Q19S, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: Q313R, dtype: float64
# tm        40.226911
# k         -1.287821
# err_tm     0.118002
# err_k      0.110711
# Name: R240A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: R240D, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: R240E, dtype: float64
# tm        39.542362
# k         -1.867525
# err_tm     0.251257
# err_k      0.467066
# Name: R240K, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: R76A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: S14A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: S16A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: S16N, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: S17A, dtype: float64
# tm        39.921090
# k         -1.091860
# err_tm     0.165549
# err_k      0.125774
# Name: S17E, dtype: float64
# tm        39.971038
# k         -1.207151
# err_tm     0.167068
# err_k      0.140808
# Name: S298E, dtype: float64
# tm        40.296757
# k         -0.872106
# err_tm     0.304353
# err_k      0.178963
# Name: S331A, dtype: float64
# tm        40.578392
# k         -1.096999
# err_tm     0.265079
# err_k      0.246864
# Name: S400A, dtype: float64
# tm        40.010901
# k         -0.983832
# err_tm     0.227281
# err_k      0.151931
# Name: T15A, dtype: float64
# tm        39.080026
# k         -0.853940
# err_tm     0.329969
# err_k      0.229038
# Name: T175R, dtype: float64
# tm        40.331942
# k         -1.351198
# err_tm     0.090771
# err_k      0.095203
# Name: T218A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: T296A, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: T352A, dtype: float64
# tm        39.536079
# k         -1.454604
# err_tm     0.174185
# err_k      0.234314
# Name: V52G, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: W120A, dtype: float64
# tm        42.337658
# k         -0.739736
# err_tm     0.272378
# err_k      0.127762
# Name: W120F, dtype: float64
# tm        40.623191
# k         -0.870755
# err_tm     0.147093
# err_k      0.094229
# Name: W120H, dtype: float64
# tm        40.779518
# k         -0.831824
# err_tm     0.435985
# err_k      0.268839
# Name: W325A, dtype: float64
# tm        39.660221
# k         -1.303152
# err_tm     0.180502
# err_k      0.188180
# Name: W325C, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: W325G, dtype: float64
# tm       NaN
# k        NaN
# err_tm   NaN
# err_k    NaN
# Name: W325H, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2d3a050e468c> in <module>()
#      20         plt.legend( loc='lower left' )
#      21         plt.tight_layout()
# ---> 22         plt.savefig( 'plots/%s.pdf' % index, format='pdf' )
#      23         plt.close()
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2534                 RendererPdf(file, image_dpi),
#    2535                 bbox_inches_restore=_bbox_inches_restore)
# -> 2536             self.figure.draw(renderer)
#    2537             renderer.finalize()
#    2538         finally:
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1108                                                                 renderer)
#    1109
#    1110         for tick in ticks_to_draw:
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1056         for tick in ticks:
#    1057             if tick.label1On and tick.label1.get_visible():
# -> 1058                 extent = tick.label1.get_window_extent(renderer)
#    1059                 ticklabelBoxes.append(extent)
#    1060             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     959             raise RuntimeError('Cannot get window extent w/o renderer')
#     960
# --> 961         bbox, info, descent = self._get_layout(self._renderer)
#     962         x, y = self.get_unitless_position()
#     963         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     473
#     474         ret = bbox, list(zip(lines, whs, xs, ys)), descent
# --> 475         self._cached[key] = ret
#     476         return ret
#     477
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py in __setitem__(self, k, v)
#    1306         if k not in self:
#    1307             if len(self) >= self.maxsize:
# -> 1308                 del self[self._killkeys[0]]
#    1309                 del self._killkeys[0]
#    1310             self._killkeys.append(k)
#
# KeyboardInterrupt:
# Error in callback <function post_execute at 0x105dc27d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py in post_execute()
#     145             def post_execute():
#     146                 if matplotlib.is_interactive():
# --> 147                     draw_all()
#     148
#     149             # IPython >= 2
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2024         if not self._is_idle_drawing:
#    2025             with self._idle_draw_cntx():
# -> 2026                 self.draw(*args, **kwargs)
#    2027
#    2028     def draw_cursor(self, event):
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1118         self._update_label_position(ticklabelBoxes, ticklabelBoxes2)
#    1119
# -> 1120         self.label.draw(renderer)
#    1121
#    1122         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     747
#     748         with _wrap_text(self) as textobj:
# --> 749             bbox, info, descent = textobj._get_layout(renderer)
#     750             trans = textobj.get_transform()
#     751
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     473
#     474         ret = bbox, list(zip(lines, whs, xs, ys)), descent
# --> 475         self._cached[key] = ret
#     476         return ret
#     477
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py in __setitem__(self, k, v)
#    1306         if k not in self:
#    1307             if len(self) >= self.maxsize:
# -> 1308                 del self[self._killkeys[0]]
#    1309                 del self._killkeys[0]
#    1310             self._killkeys.append(k)
#
# KeyError: (22.0, 0.5, u'Normalized rate', u'k', u'bottom', u'center', 3534391420781609850, u'vertical', u'anchor', 80.0, 4838981008)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     224
#     225     if 'png' in formats:
# --> 226         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     227     if 'retina' in formats or 'png2x' in formats:
#     228         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
#     116     bytes_io = BytesIO()
# --> 117     fig.canvas.print_figure(bytes_io, **kw)
#     118     data = bytes_io.getvalue()
#     119     if fmt == 'svg':
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1106         ticks_to_draw = self._update_ticks(renderer)
#    1107         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1108                                                                 renderer)
#    1109
#    1110         for tick in ticks_to_draw:
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1056         for tick in ticks:
#    1057             if tick.label1On and tick.label1.get_visible():
# -> 1058                 extent = tick.label1.get_window_extent(renderer)
#    1059                 ticklabelBoxes.append(extent)
#    1060             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     959             raise RuntimeError('Cannot get window extent w/o renderer')
#     960
# --> 961         bbox, info, descent = self._get_layout(self._renderer)
#     962         x, y = self.get_unitless_position()
#     963         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     473
#     474         ret = bbox, list(zip(lines, whs, xs, ys)), descent
# --> 475         self._cached[key] = ret
#     476         return ret
#     477
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py in __setitem__(self, k, v)
#    1306         if k not in self:
#    1307             if len(self) >= self.maxsize:
# -> 1308                 del self[self._killkeys[0]]
#    1309                 del self._killkeys[0]
#    1310             self._killkeys.append(k)
#
# KeyError: (22.0, 0.5, u'Normalized rate', u'k', u'bottom', u'center', 3534391420781609850, u'vertical', u'anchor', 80.0, 4838981008)

# %%
# diagnostics from June 21

# should have Tm but don't 
# S16A, W325L, Y294F
