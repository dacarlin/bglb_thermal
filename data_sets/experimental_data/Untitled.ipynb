# %%
import pandas 

df = pandas.read_csv( 'thermo_paper_data_set.csv', index_col=0 )
my_muts = pandas.read_csv( '/Users/alex/Documents/bagel-benchmark/data_sets/experimental/expr_144_mutants.csv', index_col=0 ) 
joined = my_muts.join( df, rsuffix='_thermo' ) 

len( joined ) 

joined[ ( joined.expression != joined.expression_thermo ) ]
# Out:
#         expression designed_res  sequence_pos  in_plos_paper  \
# mutant
# A227W            1          NaN           NaN            NaN
# A236E            0          NaN           NaN            NaN
# A249E            0          NaN           NaN            NaN
# C167S            1          NaN           NaN            NaN
# D121F            0          NaN           NaN            NaN
# E164D            1          NaN           NaN            NaN
# E222A            0            A         222.0            1.0
# E222R            1            R         222.0            1.0
# E222Y            1            Y         222.0            1.0
# E388C            1          NaN           NaN            NaN
# E423S            1          NaN           NaN            NaN
# F343S            0          NaN           NaN            NaN
# F405A            0          NaN           NaN            NaN
# F415D            0          NaN           NaN            NaN
# ...

# %%
joined
# Out:
#         expression designed_res  sequence_pos  in_plos_paper  \
# mutant
# A192S            1            S         192.0            1.0
# A227W            1          NaN           NaN            NaN
# A236E            0          NaN           NaN            NaN
# A249E            0          NaN           NaN            NaN
# C167A            1            A         167.0            1.0
# C167Q            1            Q         167.0            1.0
# C167S            1          NaN           NaN            NaN
# D121F            0          NaN           NaN            NaN
# D403A            0            A         403.0            1.0
# E154D            1            D         154.0            1.0
# E164A            1            A         164.0            1.0
# E164D            1          NaN           NaN            NaN
# E177A            1            A         177.0            1.0
# E177K            1            K         177.0            1.0
# ...
