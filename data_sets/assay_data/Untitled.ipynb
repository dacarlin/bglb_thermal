# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
plt.pcolor?

# %%
fig = plt.figure()
ax = fig.add_axes( (0,0,1,1), projection='polar' ) 
ax.pcolor( [[ 3,3,3,3,3,3, 1], [4,4,4,4,4,1, 4]], cmap='Blues' )
