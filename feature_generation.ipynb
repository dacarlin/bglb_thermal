# %%
import pandas
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Feature generation for enzymes using Rosetta

# %% [markdown]
# Here, we are determining the thermal stability of about a hundred and fifty point mutants of BglB (model based on 2JIE). After automated mutagensis of the BglB coding sequence, protein production, and protein purification, each mutant's activity at 100 mM pNPG at pH 7.4 at a range of temperatures from 30 C to 50 C was measured using the rate of formation of the pNPG hydrolysis product p-nitrophenol.
#
# We have expression data for about 150 and Tms for about 70 mutants (along with kinetic constants for another 100 or so). Let's generate some features based on the Rosetta models.

# %%
df = pandas.read_csv( 'data_sets/production.csv', index_col='mutant' )
df['pos'] = df.index.str[1:-1].astype( int )
df['designed'] = df.index.str[-1:]
df.drop( 'WT', inplace=True )

# %% [markdown]
# ```
#
# # project map
#
# data_sets/
#     production.csv
#
# protocols/
#     ddg/
#     apo_ddg/
#     enzyme_design/
#
# feature_generation.ipynb
#
# svm.ipynb
#
# ```

# %% [markdown]
# ## Rosetta modeling using `ddg_monomer`

# %%
df.sample( 5 )
# Out:
#           idx drop_me  student date_transform                   img_url  \
# mutant
# G355A    86.0   G355A  Natalie      1/31/2016  http://imgur.com/t9cHycf
# H379R    76.0   H379R     Bill      9/22/2015  http://imgur.com/JfUQmor
# N354A    92.0   N354A  Natalie      1/31/2016  http://imgur.com/oTFPr5i
# E222H   106.0   e222h    Siena      9/28/2015  http://imgur.com/RHUr9RR
# I91E     72.0    I91E    Siena      11/9/2015  http://imgur.com/SpOWrdL
#
#         colonies  grow_weight  expr_weight  beads      y    ...     \
# mutant                                                      ...
# G355A         80        292.0          174      0  0.195    ...
# H379R         12        400.0          500      0  0.211    ...
# N354A         30        458.0          406      0  0.306    ...
# E222H          2        129.0          546      0  0.369    ...
# I91E           1        127.0          179      1  0.159    ...
#
#         gel_img_exists  protein_on_gel  assay_data_exists  tm_exists  \
# mutant
# G355A                1             0.0                  1          0
# H379R                1             1.0                  1          0
# N354A                1             0.5                  1          1
# E222H                1             0.5                  1          1
# I91E                 1             1.0                  1          1
#
#               why_no_tm in_plos_paper         tm         k  pos  designed
# mutant
# G355A       no protein              1        NaN       NaN  355         A
# H379R   below detection             1        NaN       NaN  379         R
# N354A               NaN             1  40.557793 -0.335794  354         A
# E222H               NaN             1  34.708312 -0.636223  222         H
# I91E                NaN             1  39.199525 -0.443905   91         E
#
# [5 rows x 21 columns]

# %%
# make resfiles for DDG Rosetta app 

for idx, row in df.iterrows():
    with open( 'rosetta_runs/ddg_monomer/res/{}.res'.format( idx ), 'w' ) as fn:
        fn.write( 'NATRO\nSTART\n{} A PIKAA {}'.format( row.pos, row.designed ) )

# %%
# run on Cabernet with sbatch sub.sh

# %%
print len( J.omega.dropna() )
# Out:
# 60

# %%
# create pandas-parsable data 

#! ( head -1 protocols/ddg/ddg_predictions.out && grep -v desc protocols/ddg/ddg_predictions.out ) > protocols/ddg/readable_output
ddg_features = pandas.read_csv( 'rosetta_runs/results/apo_kellogg.out', sep='\s+', index_col='description' )
J = df.join( ddg_features )

J
# Out:
#          idx drop_me  student date_transform                         img_url  \
# A192S   48.0   A195S   Siena       9/22/2015        http://imgur.com/Mc8us52
# BglB    79.0   A357A    Siena     11/30/2015        http://imgur.com/jLtrOJt
# BglB    78.0   A356A     Bill      9/22/2015        http://imgur.com/zjxNeKd
# BglB    80.0   A408A     Bill      9/22/2015        http://imgur.com/NcWTJWk
# BglB     NaN      WT     Mary      8/11/2015        http://imgur.com/7D19dGa
# C167A    1.0   C167A     Bill       8/3/2015        http://imgur.com/gJGEhsm
# C167Q   31.0   C167Q     Bill     10/27/2015        http://imgur.com/ofjYcGK
# D403A   81.0   D403A     Bill      9/22/2015        http://imgur.com/299204C
# E154D   75.0   E154D     Bill      9/22/2015        http://imgur.com/F5I3lam
# E164A    2.0   E164A     Bill      11/8/2015        http://imgur.com/H7iHafM
# E164G  104.0   e164g     Bill      9/28/2015        http://imgur.com/xEcvaTx
# E164R  105.0   e164r    Siena     10/26/2015                             NaN
# E177A   82.0   E177A     Bill      9/22/2015        http://imgur.com/l9de7i8
# E177K   43.0   E177K    Siena      11/9/2015        http://imgur.com/rbmnh36
# E177L   44.0   E177L     Bill     10/20/2015        http://imgur.com/qP3e9Y6
# E222A    3.0   E222A  Natalie      11/8/2015  http://i.imgur.com/d8gHgKA.jpg
# E222H  106.0   e222h    Siena      9/28/2015        http://imgur.com/RHUr9RR
# E222K  107.0   e222k     Mary      10/5/2015        http://imgur.com/XLQUIzx
# E222Q  108.0   e222q     Mary      10/5/2015        http://imgur.com/vbRlA8H
# E222R  109.0   e222r     Mary      10/5/2015        http://imgur.com/ULnpT4l
# E222Y  110.0   e222y     Mary      10/5/2015        http://imgur.com/7DLCihC
# E353A    4.0   E353A     Bill       8/3/2015        http://imgur.com/ueVhrFR
# E406A   83.0   E406A     Mary      10/5/2015        http://imgur.com/VkrBTDc
# E406D   28.0   E406D     Bill     10/27/2015        http://imgur.com/oLselJG
# E423S   64.0   E423S     Bill      9/15/2015        http://imgur.com/lhwyYRP
# F415A   85.0   F415A  Natalie      1/31/2016        http://imgur.com/8zGXAWS
# F415N  129.0   F415N    Siena      2/29/2016        http://imgur.com/REI5DOm
# F72H    53.0    F72H    Siena      2/29/2016        http://imgur.com/xPbkWgl
# G355A   86.0   G355A  Natalie      1/31/2016        http://imgur.com/t9cHycf
# H101R   68.0   H101R     Bill      9/15/2015        http://imgur.com/yrFrpbU
# ...      ...     ...      ...            ...                             ...
# T218A   97.0   T218A     Bill      9/28/2015        http://imgur.com/JP7XQ4h
# T296A   15.0   T296A    Siena      2/29/2016        http://imgur.com/mymVeZu
# T352A   98.0   T352A     Bill      9/28/2015        http://imgur.com/KLfB76v
# V52G    65.0    V52G     Bill      9/15/2015        http://imgur.com/RaamKNK
# W120A   16.0   W120A    Siena      2/29/2016        http://imgur.com/N0fjMxw
# W120F   25.0   W120F    Siena      2/29/2016        http://imgur.com/CvQJwLR
# W120H  119.0   w120h     Bill      10/5/2015        http://imgur.com/iIckhtv
# W325A   17.0   W325A    Siena      9/28/2015       http://imgur.com/bzDDjFW
# W325C   66.0   W325C     Bill      9/15/2015        http://imgur.com/0W2zbEF
# W325G  120.0   w325g    Siena     10/26/2015                             NaN
# W325H   58.0   W325H    Siena      2/29/2016        http://imgur.com/LEuoBRe
# W325L   32.0   W325L     Bill      11/8/2015        http://imgur.com/xyC6OTG
# W325R  121.0   w325r     Bill      10/5/2015        http://imgur.com/gERKHZ9
# W34A    18.0    W34A    Siena      9/28/2015        http://imgur.com/aj5BKYu
# W399A   99.0   W399A    Siena     10/26/2015                             NaN
# W399C  123.0   w399c    Siena     11/30/2015        http://imgur.com/BSrFh4E
# W399G  124.0   w399g     Bill      11/8/2015        http://imgur.com/X8N1IBq
# W399R  133.0   W399R     Mary      8/11/2015        http://imgur.com/AdqjkcA
# W399S  122.0   w399s     Bill      10/5/2015        http://imgur.com/M509T5g
# W407A  100.0   W407A     Bill      9/28/2015        http://imgur.com/8T7yw0V
# W407G   22.0   W407G    Siena      9/28/2015        http://imgur.com/qM4M36j
# W407Q   20.0   W407Q  Natalie      11/8/2015  http://i.imgur.com/0X8b6KT.jpg
# W407R   23.0   W407R  Natalie      11/8/2015  http://i.imgur.com/uEAROyv.jpg
# W409Y  132.0   W409Y     Mary      8/11/2015        http://imgur.com/unWQlD5
# Y166P   52.0   Y166P   Siena       9/22/2015        http://imgur.com/1vfDIUx
# Y18A   101.0    Y18A     Bill      9/28/2015        http://imgur.com/VEB5R0Z
# Y294A  102.0   Y294A    Siena     10/26/2015                             NaN
# Y294F   42.0   Y294F    Siena     11/30/2015        http://imgur.com/VSrmcFa
# Y295A  103.0   Y295A     Bill     10/20/2015        http://imgur.com/Fg7Rdsi
# Y295G  126.0   y295g     Bill      11/8/2015        http://imgur.com/2woB32i
#
#        colonies  grow_weight  expr_weight  beads       y         ...           \
# A192S        10         87.0          224      0  0.3210         ...
# BglB          4        337.0          466      1  0.2840         ...
# BglB          8        300.0          500      0  0.7380         ...
# BglB         11        300.0          500      0  1.1970         ...
# BglB         25        297.0          274      0  0.2770         ...
# C167A        40          NaN          200      0  0.7700         ...
# C167Q        30        202.0          247      1  0.2640         ...
# D403A         4        200.0          400      0  0.1870         ...
# E154D        24        300.0          600      0  0.9690         ...
# E164A        75        224.0          357      1  0.1940         ...
# E164G         2        123.0          525      0  0.2910         ...
# E164R         4        121.0          400      1  0.2620         ...
# E177A        23        300.0          500      0  1.0060         ...
# E177K       100        344.0          367      1  0.1470         ...
# E177L         3        286.0          355      1  0.2320         ...
# E222A        76        425.0          526      1  0.1950         ...
# E222H         2        129.0          546      0  0.3690         ...
# E222K        13        265.0          315      0  0.0950         ...
# E222Q         5        384.0          493      0  0.3980         ...
# E222R        10        197.0          340      0  0.1460         ...
# E222Y         5        248.0          365      0  0.0910         ...
# E353A        50        300.0          200      0  0.2510         ...
# E406A        70        425.0          524      0  0.7575         ...
# E406D        15         57.0          154      1  0.5550         ...
# E423S        21        250.0          500      0  1.1900         ...
# F415A        20        350.4          364      0  0.3100         ...
# F415N        80        252.0          445      0  0.0760         ...
# F72H         20        283.0          597      0  0.1510         ...
# G355A        80        292.0          174      0  0.1950         ...
# H101R        47        250.0          300      0  1.5000         ...
# ...         ...          ...          ...    ...     ...         ...
# T218A         4        164.0          455      0  0.8800         ...
# T296A        80        344.0          520      0  0.1410         ...
# T352A         6        165.0          453      0  0.5040         ...
# V52G         14        250.0          300      0  0.9170         ...
# W120A       120        345.0          624      0  0.1330         ...
# W120F        40        284.0          587      0  0.4370         ...
# W120H         3        147.0          518      0  0.3360         ...
# W325A        56        219.0          189      0  0.2160         ...
# W325C        13        250.0          300      0  1.1210         ...
# W325G         1        296.0          356      1  0.1080         ...
# W325H        20        307.0          484      0  0.0640         ...
# W325L       100        248.0          356      1  0.3290         ...
# W325R         1        106.0          463      0  0.3540         ...
# W34A         67        294.0          410      0  0.1840         ...
# W399A         6        159.0          246      1  0.3330         ...
# W399C         3        378.0          411      1  0.4490         ...
# W399G        25        175.0          298      1  0.5210         ...
# W399R        93        269.0          343      0  0.2330         ...
# W399S         2        190.0          300      0  0.1960         ...
# W407A         5        140.0          515      0  0.1820         ...
# W407G        44        288.0          421      0  0.2760         ...
# W407Q        35        304.0          330      1  0.2510         ...
# W407R        65        367.0          660      1  0.1820         ...
# W409Y       125        206.0          338      0  0.2290         ...
# Y166P        30        146.0          267      0  0.2640         ...
# Y18A         10        123.0          475      0  0.5900         ...
# Y294A         1        239.0          373      1  0.6770         ...
# Y294F       150        322.0          479      1  0.4080         ...
# Y295A         2        243.0          418      1  0.1880         ...
# Y295G        35         93.0          399      1  0.2350         ...
#
#        coordinate_constraint  angle_constraint  dihedral_constraint   rama  \
# A192S                    NaN               NaN                  NaN    NaN
# BglB                     NaN               NaN                  NaN    NaN
# BglB                     NaN               NaN                  NaN    NaN
# BglB                     NaN               NaN                  NaN    NaN
# BglB                     NaN               NaN                  NaN    NaN
# C167A                    0.0               0.0                  0.0 -0.083
# C167Q                    0.0               0.0                  0.0  0.027
# D403A                    NaN               NaN                  NaN    NaN
# E154D                    NaN               NaN                  NaN    NaN
# E164A                    0.0               0.0                  0.0  0.098
# E164G                    0.0               0.0                  0.0 -0.048
# E164R                    0.0               0.0                  0.0 -0.147
# E177A                    NaN               NaN                  NaN    NaN
# E177K                    NaN               NaN                  NaN    NaN
# E177L                    0.0               0.0                  0.0  0.241
# E222A                    0.0               0.0                  0.0 -0.143
# E222H                    0.0               0.0                  0.0  0.059
# E222K                    NaN               NaN                  NaN    NaN
# E222Q                    0.0               0.0                  0.0 -0.139
# E222R                    0.0               0.0                  0.0 -0.300
# E222Y                    0.0               0.0                  0.0 -0.059
# E353A                    0.0               0.0                  0.0 -0.132
# E406A                    0.0               0.0                  0.0  0.276
# E406D                    0.0               0.0                  0.0  0.180
# E423S                    NaN               NaN                  NaN    NaN
# F415A                    NaN               NaN                  NaN    NaN
# F415N                    0.0               0.0                  0.0 -0.028
# F72H                     NaN               NaN                  NaN    NaN
# G355A                    0.0               0.0                  0.0  0.505
# H101R                    0.0               0.0                  0.0 -0.113
# ...                      ...               ...                  ...    ...
# T218A                    0.0               0.0                  0.0  0.181
# T296A                    0.0               0.0                  0.0  0.074
# T352A                    NaN               NaN                  NaN    NaN
# V52G                     NaN               NaN                  NaN    NaN
# W120A                    NaN               NaN                  NaN    NaN
# W120F                    NaN               NaN                  NaN    NaN
# W120H                    NaN               NaN                  NaN    NaN
# W325A                    0.0               0.0                  0.0 -0.199
# W325C                    NaN               NaN                  NaN    NaN
# W325G                    NaN               NaN                  NaN    NaN
# W325H                    NaN               NaN                  NaN    NaN
# W325L                    NaN               NaN                  NaN    NaN
# W325R                    NaN               NaN                  NaN    NaN
# W34A                     NaN               NaN                  NaN    NaN
# W399A                    0.0               0.0                  0.0 -0.269
# W399C                    NaN               NaN                  NaN    NaN
# W399G                    0.0               0.0                  0.0 -0.016
# W399R                    0.0               0.0                  0.0 -0.085
# W399S                    0.0               0.0                  0.0 -0.331
# W407A                    0.0               0.0                  0.0 -0.235
# W407G                    0.0               0.0                  0.0 -0.203
# W407Q                    0.0               0.0                  0.0  0.089
# W407R                    0.0               0.0                  0.0  0.295
# W409Y                    0.0               0.0                  0.0  0.096
# Y166P                    0.0               0.0                  0.0  0.364
# Y18A                     0.0               0.0                  0.0 -0.392
# Y294A                    0.0               0.0                  0.0 -0.076
# Y294F                    0.0               0.0                  0.0 -0.344
# Y295A                    0.0               0.0                  0.0  0.170
# Y295G                    0.0               0.0                  0.0  0.310
#
#        omega fa_dun  p_aa_pp    ref  chainbreak  res_type_constraint
# A192S    NaN    NaN      NaN    NaN         NaN                  NaN
# BglB     NaN    NaN      NaN    NaN         NaN                  NaN
# BglB     NaN    NaN      NaN    NaN         NaN                  NaN
# BglB     NaN    NaN      NaN    NaN         NaN                  NaN
# BglB     NaN    NaN      NaN    NaN         NaN                  NaN
# C167A -0.056  0.009   -0.341  0.238         0.0                  0.0
# C167Q  0.408  3.564   -0.163 -1.533         0.0                  0.0
# D403A    NaN    NaN      NaN    NaN         NaN                  NaN
# E154D    NaN    NaN      NaN    NaN         NaN                  NaN
# E164A  0.187 -2.898    0.155  2.147         0.0                  0.0
# E164G -0.284 -1.910   -0.202  1.694         0.0                  0.0
# E164R -0.105  0.377   -0.378  1.405         0.0                  0.0
# E177A    NaN    NaN      NaN    NaN         NaN                  NaN
# E177K    NaN    NaN      NaN    NaN         NaN                  NaN
# E177L  0.024 -2.587    0.061  2.156         0.0                  0.0
# E222A -0.134 -3.983   -0.114  2.147         0.0                  0.0
# E222H -0.305 -3.472   -0.311  1.911         0.0                  0.0
# E222K    NaN    NaN      NaN    NaN         NaN                  NaN
# E222Q -0.347  0.149   -0.200  0.376         0.0                  0.0
# E222R -0.300 -2.195   -0.333  1.405         0.0                  0.0
# E222Y -0.018 -3.950   -0.318  1.685         0.0                  0.0
# E353A -0.306 -0.809    0.026  2.147         0.0                  0.0
# E406A -0.260 -3.149   -0.041  2.147         0.0                  0.0
# E406D -0.406 -1.290   -0.126  0.267         0.0                  0.0
# E423S    NaN    NaN      NaN    NaN         NaN                  NaN
# F415A    NaN    NaN      NaN    NaN         NaN                  NaN
# F415N -0.218 -0.191   -0.089 -1.373         0.0                  0.0
# F72H     NaN    NaN      NaN    NaN         NaN                  NaN
# G355A -0.300  0.575    1.286  0.452         0.0                  0.0
# H101R -0.057 -0.164   -0.202 -0.507         0.0                  0.0
# ...      ...    ...      ...    ...         ...                  ...
# T218A -0.045  0.073    0.436  0.428         0.0                  0.0
# T296A -0.084 -0.250   -0.405  0.428         0.0                  0.0
# T352A    NaN    NaN      NaN    NaN         NaN                  NaN
# V52G     NaN    NaN      NaN    NaN         NaN                  NaN
# W120A    NaN    NaN      NaN    NaN         NaN                  NaN
# W120F    NaN    NaN      NaN    NaN         NaN                  NaN
# W120H    NaN    NaN      NaN    NaN         NaN                  NaN
# W325A  0.044 -1.105    0.106 -0.336         0.0                  0.0
# W325C    NaN    NaN      NaN    NaN         NaN                  NaN
# W325G    NaN    NaN      NaN    NaN         NaN                  NaN
# W325H    NaN    NaN      NaN    NaN         NaN                  NaN
# W325L    NaN    NaN      NaN    NaN         NaN                  NaN
# W325R    NaN    NaN      NaN    NaN         NaN                  NaN
# W34A     NaN    NaN      NaN    NaN         NaN                  NaN
# W399A  0.246 -0.980    0.578 -0.336         0.0                  0.0
# W399C    NaN    NaN      NaN    NaN         NaN                  NaN
# W399G -0.395  1.466    0.346 -0.789         0.0                  0.0
# W399R  0.444  2.229   -0.137 -1.078         0.0                  0.0
# W399S  0.365 -0.263    0.337 -0.753         0.0                  0.0
# W407A -0.126 -2.435   -0.637 -0.336         0.0                  0.0
# W407G -0.226 -2.370   -1.135 -0.789         0.0                  0.0
# W407Q -0.130  0.388   -0.575 -2.107         0.0                  0.0
# W407R -0.129 -0.442   -0.729 -1.078         0.0                  0.0
# W409Y -0.248 -0.424   -0.175 -0.798         0.0                  0.0
# Y166P  0.037 -1.220    0.190 -0.351         0.0                  0.0
# Y18A   0.165 -1.602   -0.178  0.461         0.0                  0.0
# Y294A -0.205 -3.272    0.109  0.461         0.0                  0.0
# Y294F  0.283 -0.860    0.556  0.299         0.0                  0.0
# Y295A  0.217 -1.318    0.532  0.461         0.0                  0.0
# Y295G -0.038 -1.269    0.517  0.009         0.0                  0.0
#
# [119 rows x 44 columns]

# %%
# colored by expression 

plt.scatter( J.fa_rep, J.total, c=J.protein_on_gel, cmap='gray' )
plt.xlabel( 'fa_rep' )
plt.ylabel( 'total_score' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-db41c3010dab> in <module>()
#       1 # colored by expression
#       2
# ----> 3 plt.scatter( J.fa_rep, J.total, c=J.protein_on_gel, cmap='gray' )
#       4 plt.xlabel( 'fa_rep' )
#       5 plt.ylabel( 'total_score' )
#
# NameError: name 'J' is not defined

# %% [markdown]
# ## Enzyme design features
#
# ### Elastic net for feature selection and prediction of continuous variable $T_M$

# %%
# read in and clean up the feature set 

import pandas

def low_10( df ):
    return df.sort_values( [ 'all_cst', 'total_score' ] ).head( 10 ).mean()

models = pandas.read_csv( 'protocols/enzyme_design/scorefile.csv' ) 
grouped = models.groupby( 'name' ).apply( low_10 ) 

df = pandas.read_csv( 'data/clean/production.csv', index_col='mutant' ) 
df['norm_tm'] = df.tm - 39.5

J = df.join( grouped )

# clean up data for sklearn
x_cols = [ u'total_score', u'fa_rep', u'hbond_sc', u'tot_pstat_pm',
       u'tot_nlpstat_pm', u'tot_burunsat_pm', u'tot_hbond_pm',
       u'tot_NLconts_pm', u'tot_nlsurfaceE_pm', u'tot_total_charge',
       u'SR_1_total_score', u'SR_1_fa_rep', u'SR_1_hbond_sc',
       u'SR_1_hbond_pm', u'SR_1_burunsat_pm',
       u'SR_1_pstat_pm', u'SR_1_nlpstat_pm', u'SR_2_total_score',
       u'SR_2_fa_rep', u'SR_2_hbond_sc', u'SR_2_all_cst', u'SR_2_hbond_pm',
       u'SR_2_burunsat_pm', u'SR_2_pstat_pm', u'SR_2_nlpstat_pm',
       u'SR_3_total_score', u'SR_3_fa_rep', u'SR_3_hbond_sc', 
       u'SR_3_hbond_pm', u'SR_3_burunsat_pm', u'SR_3_pstat_pm',
       u'SR_3_nlpstat_pm', u'SR_4_total_score', u'SR_4_fa_rep',
       u'SR_4_hbond_sc', u'SR_4_hbond_pm',
       u'SR_4_burunsat_pm', u'SR_4_pstat_pm', u'SR_4_nlpstat_pm',
       u'SR_5_total_score', u'SR_5_fa_rep', u'SR_5_hbond_sc', u'SR_5_all_cst',
       u'SR_5_interf_E_1_2', u'SR_5_dsasa_1_2', u'SR_5_hbond_pm',
       u'SR_5_burunsat_pm', 'tm' ]

J = J[ x_cols ]
J.to_csv( 'protocols/enzyme_design/feature_set.csv' )

# %%
# train and evaluate classifiers for predicting tm 

from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import BaggingRegressor
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.learning_curve import validation_curve
from scipy.stats import pearsonr
import pandas
import matplotlib.pyplot as plt 
# %matplotlib inline

# read in data 

df = pandas.read_csv( 'protocols/enzyme_design/feature_set.csv', index_col=0 ).dropna()
df['norm_tm'] = df.tm - 39.5 # BglB native Tm

# construct pipeline 

L = [ 0.03, 0.1, 0.3, 0.9, 0.95, 0.97 ] 

param_grid = [
    { 
        'en__l1_ratio': L, 
        'en__selection': 'random', 
    }, 
]

pln = Pipeline([
    ( 'scaler', preprocessing.StandardScaler() ), 
    ( 'en', BaggingRegressor( ElasticNetCV( cv=10, selection='random' ), n_estimators=1, n_jobs=-1 ) ), 
])

X = df.drop( [ 'tm', 'norm_tm' ], axis=1 ) 
y = df.norm_tm 

plt.figure( figsize=(3, 3) )
plt.title( 'Elastic net with bagging performance' ) 
plt.xlabel( 'N-fold cross validation' ) 
plt.ylabel( 'Model score' ) 

for i in range( 2, 10 ):
    pln.fit( X, y ) 
    score = pln.score( X, y )
    
    plt.scatter( i, score ) 
    plt.plot( i, score, alpha=0.1 ) 

plt.show?

# %%
from sklearn import svm, cross_validation
from sklearn.metrics import roc_curve 

df = pandas.read_csv( 'protocols/enzyme_design/feature_set.csv', index_col=0 ).dropna()

X = df.drop( [ 'tm', 'protein_on_gel' ], axis=1 ) 

scaler = preprocessing.StandardScaler()
X = scaler.fit_transform( X ) 

y = df.protein_on_gel.round()

plt.figure( figsize=(4,4) )

classifiers = [
    ( 'linear svm', svm.SVC( kernel='linear', C=0.3 ) ), 
    ( 'RBF svm', svm.SVC( kernel='rbf', C=3. ) ), 
]

legend = []
for name, clf in classifiers:
    
    print cross_validation.cross_val_score( clf, X, y, cv=8 ) 
    
    clf.fit( X, y )
    preds = clf.predict( X ) 
    dec = clf.decision_function( X ) 

    fpr_train, tpr_train, __ = roc_curve( y, dec ) 

    plt.plot( fpr_train, tpr_train ) 
    leg.append( name ) 

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.02, 1.02])
plt.ylim([-0.02, 1.02])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SVM results')
plt.legend( legend, loc='lower right' )
plt.show()

cross_validation.cross_val_score?
# Out:
# [ 0.875       0.375       0.75        0.75        0.625       0.75
#   0.85714286  0.71428571]
# [ 0.875       0.75        0.875       0.875       0.625       0.625
#   0.85714286  0.85714286]

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC 

pipe_svc = Pipeline
