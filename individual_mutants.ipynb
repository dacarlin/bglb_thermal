# %% [markdown]
# # `individual_mutants`
#
# Highlights of individual mutants

# %%
import pandas 
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.style.use( 'bmh' )

# %% [markdown]
# We will attempt to make a six-panel figure, with the top 3 and bottom 3 mutants in terms of their effect on $T_m$.

# %%
mutants_of_interest = [ 
    'N404C', 
    'W409Y', 
    'E177K', 
    'E222H', 
    'E164A', 
    'W325L', 
]

# %%
master = pandas.read_csv( 'data_sets/data_set.csv', index_col=0 )

# %%
fig, ax = plt.subplots( nrows=1, ncols=6, figsize=(24,4) ) 

for i, mutant in enumerate( mutants_of_interest ):
    
    ax[i].set_title( mutant ) 
    params = master.loc[ mutant ] 
    wt_params = master.loc[ 'BglB' ]
