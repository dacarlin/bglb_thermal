# %%
# %matplotlib inline

import pandas
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
from matplotlib import rc, cm
from numpy import log, inf, nan

# %%
df = pandas.read_csv( '../data_sets/experimental_data/thermo_paper_data_set.csv', index_col=0 ) 
df = df.sort_values( 'sequence_pos' ) 

## Figure 1: overview

# %%
## Miscellaneous for paper 

### Number of uniq seq positions mutated 

len( df.sequence_pos.unique() )
# Out:
# 68

# %%
# figure 1: overview 

s = '+'.join( [ i for i in df.sequence_pos.dropna().astype( int ).astype( str ) ] ) 
print 'select all_mutants, resi', s
# Out:
# select all_mutants, resi ...

# %%
# mutants that don't express 

no_express = df[( df.expression < 1 )]
print no_express.sample( 3 )
# Out:
#         sequence_pos  tm   why_no_tm   kcat  ekcat    km  ekm  ki  eki  \
# mutant
# G12N            12.0 NaN         NaN    NaN    NaN   NaN  NaN NaN  NaN
# M221A          221.0 NaN  no protein  547.0   15.0  6.25  0.6 NaN  NaN
# T296E          296.0 NaN         NaN    NaN    NaN   NaN  NaN NaN  NaN
#
#          kcatkm  ekcatkm  in_plos_paper  added_later  expression gel_number  \
# mutant
# G12N        NaN      NaN              0            1           0        NaN
# M221A   87554.0   8701.0              1            0           0          4
# T296E       NaN      NaN              0            1           0        NaN
#
#        note
# mutant
# G12N    NaN
# M221A   NaN
# T296E   NaN

# %%
# conservation 

dat = pandas.read_csv( 'alignments/logo-data-bagel-aligned.txt', sep='\s+' ) 
dat['sequence_pos'] = dat.index + 1

# %%
dat.columns
# Out:
# Index([u'amino_acid', u'#', u'A', u'C', u'D', u'E', u'F', u'G', u'H', u'I',
#        u'K', u'L', u'M', u'N', u'P', u'Q', u'R', u'S', u'T', u'V', u'W', u'Y',
#        u'Entropy', u'Low', u'High', u'Weight', u'1', u'sequence_pos'],
#       dtype='object')

# %%
aas = [ u'A', u'C', u'D', u'E', u'F', u'G', u'H', u'I', u'K', u'L', u'M', u'N', u'P', u'Q', u'R', u'S', u'T', u'V', u'W', u'Y' ]

# %%
clean_dat = dat[ aas ] # + [ 'amino_acid' ] ].copy()
clean_dat.index = dat.amino_acid 

percents = []
for idx, row in clean_dat.iterrows():
    #print idx, row[ idx.upper() ].astype( float ) / row.sum() * 100, 'per cent', idx 
    percents.append( row[ idx.upper() ].astype( float ) / row.sum()  )
    
clean_dat['percents'] = percents
clean_dat['sequence_pos'] = range( 1, 446 )
# Out:
# /Users/alex/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/alex/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.figure( figsize=( 30, 5 ) ) 
plt.scatter( dat.sequence_pos, ( dat.Entropy / dat.Entropy.max()) ,color='k', label='Entropy (normalized to 1)' )
#plt.bar( clean_dat.sequence_pos, clean_dat.percents, lw=0, color='blue', label='Percent conserved' ) 
plt.plot( clean_dat.sequence_pos, clean_dat.percents, color='g', label='Percent conserved' ) 

plt.xlim( 0, 446 ) 
plt.ylim( 0, 1.2 ) 
plt.xticks( [ 100, 200, 300, 400 ] ) 
plt.yticks( [ 0.2, 0.4, 0.6, 0.8, 1. ] ) 
plt.legend()
plt.show()

# %%
# heat map 

from numpy import log10

heatmap_cols = [ 'expression', 'tm', 'kcat', 'km', 'kcatkm' ] 
heatmap_data = df[ heatmap_cols ].copy()

heatmap_data['n_tm'] = heatmap_data.tm - 39.6
heatmap_data['n_kcat'] = log10( heatmap_data.kcat / 880 ) 
heatmap_data['n_km'] = log10( (1/heatmap_data.km) / (1/5.05) )
heatmap_data['n_kcatkm'] = log10( heatmap_data.kcatkm / 174000 )  
heatmap_data['n_expr'] = heatmap_data.expression 

heatmap_data.replace( [ -inf ], -5, inplace=True )  
heatmap_data.sample( 5 )
# Out:
#         expression    tm    kcat    km    kcatkm  n_tm    n_kcat      n_km  \
# mutant
# T218A            1  40.0   464.0  6.51   71280.0   0.4 -0.277965 -0.110290
# W325G            0   NaN     NaN   NaN       NaN   NaN       NaN       NaN
# A236E            0   NaN     NaN   NaN       NaN   NaN       NaN       NaN
# H315E            1   NaN     NaN   NaN      10.0   NaN       NaN       NaN
# K341A            1  40.0  1046.0  5.46  191689.0   0.4  0.075049 -0.033901
#
#         n_kcatkm  n_expr
# mutant
# T218A  -0.387582       1
# W325G        NaN       0
# A236E        NaN       0
# H315E  -4.240549       1
# K341A   0.042048       1

# %%
img_cols = [ 'n_expr', 'n_tm', 'n_kcat', 'n_km', 'n_kcatkm' ]
heatmap = heatmap_data[ img_cols ].copy().replace( [-inf,inf], -5 )  
heatmap.loc[ 'BglB' ] = ( 1, 0, 0, 0, 0 )  

print heatmap.sample( 5 )
# Out:
#         n_expr  n_tm    n_kcat      n_km  n_kcatkm
# mutant
# N163D        1  -1.3 -1.865301 -0.478266 -2.343472
# N220H        1  -0.1 -0.854578 -0.007672 -0.862624
# E177A        1  -2.3  0.049394 -0.073410 -0.023581
# S298E        1   0.0 -0.036534 -0.019343 -0.055109
# H315E        1   NaN       NaN       NaN -4.240549

# %%
# color map 

from matplotlib import pyplot
import matplotlib as mpl

# Make a figure and axes with dimensions as desired.
fig = pyplot.figure(figsize=(8, 3))
ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# The third example illustrates the use of custom length colorbar
# extensions, used on a colorbar with discrete intervals.
cmap = mpl.colors.ListedColormap(
    
[( 0.11, .19, .36 ), # deep blue
( .46, .57, .66 ), # medium blue
( .71, .76, .80 ), # light blue 
( .92, .92, .92 ), # grey 
( .92, .88, .74 ), # light yellow
( .88, .80, .51 ), # medium yellow 
( .81, .63, 0. )])

cmap.set_over((1., 0., 0.))
cmap.set_under((0., 0., 1.))

bounds = [-5., -2.5, -.5, -.5, .5, 1, 1.5]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
cb3 = mpl.colorbar.ColorbarBase(ax3, cmap=cmap,
                                norm=norm,
#                                 boundaries=[-10] + bounds + [10],
#                                 extend='both',
#                                 # Make the length of each extension
#                                 # the same as the length of the
#                                 # interior colors:
#                                 extendfrac='auto',
                                ticks=bounds+[0],
#                                 spacing='uniform',
                                orientation='horizontal')
cb3.set_label('Custom extension lengths, some other units')
pyplot.show()

# %%
heatmap.describe()
# Out:
# /Users/alex/Applications/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            n_expr       n_tm     n_kcat       n_km   n_kcatkm
# count  129.000000  62.000000  80.000000  80.000000  81.000000
# mean     0.666667  -0.516129  -0.870259  -0.141637  -1.431846
# std      0.473242   1.678426   1.053543   0.460947   1.506502
# min      0.000000  -6.700000  -5.000000  -1.246976  -4.240549
# 25%      0.000000        NaN        NaN        NaN        NaN
# 50%      1.000000        NaN        NaN        NaN        NaN
# 75%      1.000000        NaN        NaN        NaN        NaN
# max      1.000000   3.000000   1.097344   2.004321   0.512085

# %%
# heat map columns 

plt.figure( figsize=(18,36) ) 
plt.subplots_adjust(left=-11.1)
#plt.subplots_adjust(left=-11.46)
rc('axes', edgecolor='none')

# font = { 'size': 14, 'name': 'Source Sans Pro' }
# rc('font', **font)

plt.subplot( 1, 6, 1 )
plt.imshow( heatmap[ ['n_expr'] ], interpolation='none', cmap='Greys' ) 
plt.tick_params( length=0 ) 
plt.xticks( [ 0 ], [ 'SDS-PAGE' ], rotation='vertical' ); plt.yticks( [] ) 
plt.yticks( range( len( heatmap.index ) ), heatmap.index, fontname='Source Sans Pro' )
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 2 )
plt.imshow( heatmap[ ['n_tm'] ], interpolation='none', cmap='bwr', vmin=-6, vmax=6 ) 
plt.xticks( [ 0 ], [ '$T_m$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 3 )
plt.imshow( heatmap[ ['n_kcat'] ], interpolation='none', cmap='PuOr', vmin=-5, vmax=5 ) 
plt.xticks( [ 0 ], [ '$k_{cat}$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 4 )
plt.imshow( heatmap[ ['n_km'] ], interpolation='none', cmap='PuOr', vmin=-5, vmax=5  ) 
plt.xticks( [ 0 ], [ '$K_M$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 5 )
plt.imshow( heatmap[ ['n_kcatkm'] ], interpolation='none', cmap='PuOr', vmin=-5, vmax=5  ) 
plt.xticks( [ 0 ], [ '$k_{cat}/K_M$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.tight_layout()
#plt.savefig( 'fig2/plt_out.png', dpi=300 ) 
plt.show()
# Out:
# /Users/alex/Applications/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'Source Sans Pro'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# bar plot style 

import numpy as np 

plt.figure( figsize=(.5,30) ) 
#plt.subplots_adjust(left=-11.8)
#plt.subplots_adjust(left=-11.46)
#rc('axes', edgecolor='none')
font = { 'size': 10 }
rc('font', **font)

#plt.subplot( 1, 6, 1 )
x_vals = [ i + 0.5 for i in range( len( heatmap ) ) ]
plt.barh( x_vals, heatmap.n_kcat, color='k', height=0.1)
plt.tick_params( length=0 ) 
plt.yticks( range( len( heatmap.index ) ), heatmap.index )
plt.show()
