# %%
# all positions mutated 

import pandas 

df = pandas.read_csv( 'data/clean/production.csv', index_col='mutant' )
df['pos'] = df.index.str[1:-1].astype( int )

print 'select muts, resi', '+'.join( df.pos.astype( str ) )
# Out:
# select muts, resi ...

# %% [markdown]
# ![](img/all_positions.png)

# %%
# heatmap 

# %matplotlib inline 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
from matplotlib import rc 
from numpy import log
import pandas 

df = pandas.read_csv( 'data/clean/production.csv', index_col='mutant' )
plos = pandas.read_csv( '/Users/alex/Documents/bagel-data/clean_data/plos2015.csv', index_col='name' )
df = df.join( plos, rsuffix='plos_' ) 

df['norm_tm'] = df[ 'tm' ] - 39.5
df['norm_kcat'] = log( df[ 'kcat' ] / 880 ) - 1
df['norm_km'] = log( df[ 'km' ] / 0.05 ) - 1
df['norm_kcatkm'] = log( df[ 'kcatkm' ] / 174000 ) - 1
df['pos'] = df.index.str[1:-1].astype( int ) 
df = df.sort_values( by='pos' )

df
# Out:
#          idx drop_me  student date_transform                         img_url  \
# S14A    94.0    S14A  Natalie      1/31/2016        http://imgur.com/M9wjuRL
# T15A    96.0    T15A     Bill      9/28/2015        http://imgur.com/uH1FNX6
# S16A    13.0    S16A  Natalie      11/8/2015  http://i.imgur.com/HwXKOLT.jpg
# S16A    59.0    S16A      NaN            NaN                             NaN
# S16N   135.0    S16N     Mary      8/11/2015        http://imgur.com/lIvxQzT
# S17A    95.0    S17A  Natalie      1/31/2016        http://imgur.com/rekX0s9
# S17E    29.0    S17E     Bill     10/27/2015        http://imgur.com/sJ4VZ6c
# Y18A   101.0    Y18A     Bill      9/28/2015        http://imgur.com/VEB5R0Z
# Q19C   114.0    q19c     Bill      10/5/2015        http://imgur.com/MorA18r
# Q19A    10.0    Q19A    Siena      2/29/2016        http://imgur.com/GoG02mT
# Q19S    55.0    Q19s   Siena       9/22/2015        http://imgur.com/aiHfZ3D
# W34A    18.0    W34A    Siena      9/28/2015        http://imgur.com/aj5BKYu
# V52G    65.0    V52G     Bill      9/15/2015        http://imgur.com/RaamKNK
# F72H    53.0    F72H    Siena      2/29/2016        http://imgur.com/xPbkWgl
# R76A    12.0    R76A  Natalie      11/8/2015  http://i.imgur.com/tKuddaM.jpg
# I91E    72.0    I91E    Siena      11/9/2015        http://imgur.com/SpOWrdL
# H101R   68.0   H101R     Bill      9/15/2015        http://imgur.com/yrFrpbU
# H119A   87.0   H119A  Natalie      1/31/2016        http://imgur.com/CSra5sE
# H119E   40.0   H119E     Bill     10/20/2015        http://imgur.com/aFWt2Bx
# H119N   56.0   H119N   Siena       9/22/2015        http://imgur.com/71myLWa
# W120F   25.0   W120F    Siena      2/29/2016        http://imgur.com/CvQJwLR
# W120H  119.0   w120h     Bill      10/5/2015        http://imgur.com/iIckhtv
# W120A   16.0   W120A    Siena      2/29/2016        http://imgur.com/N0fjMxw
# V147S   73.0   V147S      NaN            NaN                             NaN
# E154D   75.0   E154D     Bill      9/22/2015        http://imgur.com/F5I3lam
# N163A   91.0   N163A  Natalie      1/31/2016        http://imgur.com/pL9x4DH
# N163C  112.0   n163c     Mary      10/5/2015        http://imgur.com/FX85Fwr
# N163D   67.0   N166D      NaN            NaN                             NaN
# N163D  113.0   n163d     Bill      10/5/2015        http://imgur.com/1CWSB4l
# E164G  104.0   e164g     Bill      9/28/2015        http://imgur.com/xEcvaTx
# ...      ...     ...      ...            ...                             ...
# H379R   76.0   H379R     Bill      9/22/2015        http://imgur.com/JfUQmor
# H379T   69.0   H379T     Bill      9/15/2015        http://imgur.com/zHi4wOM
# Q384R   77.0   Q384R      NaN            NaN                             NaN
# W399S  122.0   w399s     Bill      10/5/2015        http://imgur.com/M509T5g
# W399R  133.0   W399R     Mary      8/11/2015        http://imgur.com/AdqjkcA
# W399C  123.0   w399c    Siena     11/30/2015        http://imgur.com/BSrFh4E
# W399G  124.0   w399g     Bill      11/8/2015        http://imgur.com/X8N1IBq
# W399C   61.0   W399C      NaN            NaN                             NaN
# W399S  125.0   w399s      NaN            NaN                             NaN
# W399A   99.0   W399A    Siena     10/26/2015                             NaN
# S400A   14.0   S400A    Siena      2/29/2016        http://imgur.com/JIuwX9e
# D403A   81.0   D403A     Bill      9/22/2015        http://imgur.com/299204C
# N404A   93.0   N404A  Natalie      1/31/2016        http://imgur.com/XOVCqnq
# N404C   63.0   N404C    Siena      2/29/2016        http://imgur.com/qcE63NW
# F405A   84.0   F405A      NaN            NaN                             NaN
# E406A   83.0   E406A     Mary      10/5/2015        http://imgur.com/VkrBTDc
# E406D   28.0   E406D     Bill     10/27/2015        http://imgur.com/oLselJG
# W407Q   27.0   W407Q      NaN            NaN                             NaN
# W407R   23.0   W407R  Natalie      11/8/2015  http://i.imgur.com/uEAROyv.jpg
# W407G   22.0   W407G    Siena      9/28/2015        http://imgur.com/qM4M36j
# W407A  100.0   W407A     Bill      9/28/2015        http://imgur.com/8T7yw0V
# W407Q   20.0   W407Q  Natalie      11/8/2015  http://i.imgur.com/0X8b6KT.jpg
# A408A   80.0   A408A     Bill      9/22/2015        http://imgur.com/NcWTJWk
# W409A   19.0   W409A      NaN            NaN                             NaN
# W409Y  132.0   W409Y     Mary      8/11/2015        http://imgur.com/unWQlD5
# K413A   88.0   K413A      NaN            NaN                             NaN
# F415A   85.0   F415A  Natalie      1/31/2016        http://imgur.com/8zGXAWS
# F415N  129.0   F415N    Siena      2/29/2016        http://imgur.com/REI5DOm
# E423S   64.0   E423S     Bill      9/15/2015        http://imgur.com/lhwyYRP
# WT       NaN      WT     Mary      8/11/2015        http://imgur.com/7D19dGa
#
#        colonies  grow_weight  expr_weight  beads       y         ...           \
# S14A       15.0        486.0        411.0    0.0  0.4130         ...
# T15A        4.0        236.0        502.0    0.0  0.6190         ...
# S16A       80.0        328.0        422.0    1.0  0.5040         ...
# S16A        NaN          NaN          NaN    NaN     NaN         ...
# S16N       75.0        297.0        361.0    0.0  0.1790         ...
# S17A       30.0        465.0        416.0    0.0  0.5020         ...
# S17E       27.0        325.0        315.0    1.0  0.2020         ...
# Y18A       10.0        123.0        475.0    0.0  0.5900         ...
# Q19C        3.0         95.0        558.0    0.0  0.4790         ...
# Q19A       50.0        295.0        408.0    0.0  0.4100         ...
# Q19S       25.0        137.0        270.0    0.0  0.1830         ...
# W34A       67.0        294.0        410.0    0.0  0.1840         ...
# V52G       14.0        250.0        300.0    0.0  0.9170         ...
# F72H       20.0        283.0        597.0    0.0  0.1510         ...
# R76A      100.0        273.0        430.0    1.0  0.4860         ...
# I91E        1.0        127.0        179.0    1.0  0.1590         ...
# H101R      47.0        250.0        300.0    0.0  1.5000         ...
# H119A       3.0        468.0        426.0    0.0  0.2770         ...
# H119E       7.0        271.0        534.0    1.0  0.1680         ...
# H119N      25.0        183.0        286.0    0.0  0.1130         ...
# W120F      40.0        284.0        587.0    0.0  0.4370         ...
# W120H       3.0        147.0        518.0    0.0  0.3360         ...
# W120A     120.0        345.0        624.0    0.0  0.1330         ...
# V147S       NaN          NaN          NaN    NaN     NaN         ...
# E154D      24.0        300.0        600.0    0.0  0.9690         ...
# N163A      15.0        354.0        441.0    0.0  0.1630         ...
# N163C      45.0        215.0        309.0    0.0  0.1190         ...
# N163D       NaN          NaN          NaN    NaN     NaN         ...
# N163D       8.0        311.0        345.0    0.0  0.6870         ...
# E164G       2.0        123.0        525.0    0.0  0.2910         ...
# ...         ...          ...          ...    ...     ...         ...
# H379R      12.0        400.0        500.0    0.0  0.2110         ...
# H379T      14.0        250.0        200.0    0.0  0.6570         ...
# Q384R       NaN          NaN          NaN    NaN     NaN         ...
# W399S       2.0        190.0        300.0    0.0  0.1960         ...
# W399R      93.0        269.0        343.0    0.0  0.2330         ...
# W399C       3.0        378.0        411.0    1.0  0.4490         ...
# W399G      25.0        175.0        298.0    1.0  0.5210         ...
# W399C       NaN          NaN          NaN    NaN     NaN         ...
# W399S       NaN          NaN          NaN    NaN     NaN         ...
# W399A       6.0        159.0        246.0    1.0  0.3330         ...
# S400A      30.0        294.0        630.0    0.0  0.2360         ...
# D403A       4.0        200.0        400.0    0.0  0.1870         ...
# N404A       3.0        515.0        346.0    0.0  0.5320         ...
# N404C       8.0        285.0        385.0    0.0  0.1450         ...
# F405A       NaN          NaN          NaN    NaN     NaN         ...
# E406A      70.0        425.0        524.0    0.0  0.7575         ...
# E406D      15.0         57.0        154.0    1.0  0.5550         ...
# W407Q       NaN          NaN          NaN    NaN     NaN         ...
# W407R      65.0        367.0        660.0    1.0  0.1820         ...
# W407G      44.0        288.0        421.0    0.0  0.2760         ...
# W407A       5.0        140.0        515.0    0.0  0.1820         ...
# W407Q      35.0        304.0        330.0    1.0  0.2510         ...
# A408A      11.0        300.0        500.0    0.0  1.1970         ...
# W409A       NaN          NaN          NaN    NaN     NaN         ...
# W409Y     125.0        206.0        338.0    0.0  0.2290         ...
# K413A       NaN          NaN          NaN    NaN     NaN         ...
# F415A      20.0        350.4        364.0    0.0  0.3100         ...
# F415N      80.0        252.0        445.0    0.0  0.0760         ...
# E423S      21.0        250.0        500.0    0.0  1.1900         ...
# WT         25.0        297.0        274.0    0.0  0.2770         ...
#
#        ekcat      ki    eki    kcatkm  ekcatkm   norm_tm  norm_kcat   norm_km  \
# S14A    11.0     NaN    NaN   38823.0   4972.0  0.517869  -2.011601  4.105945
# T15A     NaN     NaN    NaN       NaN      NaN -0.803077        NaN       NaN
# S16A     1.0     NaN    NaN   10997.0    331.0       NaN  -2.742969  4.635504
# S16A     1.0     NaN    NaN   10997.0    331.0       NaN  -2.742969  4.635504
# S16N     NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# S17A    76.0     NaN    NaN   45978.0  10135.0  2.149042  -1.037041  4.910797
# S17E     9.0     NaN    NaN   87596.0   4719.0 -0.070108  -1.316892  3.986343
# Y18A     9.0     NaN    NaN    6230.0    773.0 -2.327097  -2.496718  5.447306
# Q19C     NaN     NaN    NaN       1.0      0.0       NaN        NaN       NaN
# Q19A     NaN     NaN    NaN      11.0      3.0       NaN        NaN       NaN
# Q19S     NaN     NaN    NaN      13.0      3.0 -3.029027        NaN       NaN
# W34A     NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# V52G    13.0     NaN    NaN   83371.0   5707.0 -0.293701  -1.247588  4.105945
# F72H     NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# R76A     NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# I91E    35.0     NaN    NaN  126071.0  15714.0 -0.300475  -1.039403  3.899331
# H101R   16.0     NaN    NaN   99708.0   5225.0  0.521708  -0.814842  4.358471
# H119A   11.0     NaN    NaN    9483.0   2222.0  0.658045  -2.817077  4.710427
# H119E    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# H119N    1.0     NaN    NaN      82.0      8.0       NaN  -7.086775  5.140746
# W120F   21.0     NaN    NaN   29334.0   3980.0  2.010527  -1.622943  4.773309
# W120H    2.0     NaN    NaN     943.0     53.0  0.388395  -3.349105  6.486389
# W120A    NaN     NaN    NaN       1.0      0.0       NaN        NaN       NaN
# V147S    1.0     NaN    NaN     706.0     70.0       NaN  -6.170484  3.859812
# E154D   47.0     NaN    NaN  254004.0  57175.0 -0.800896  -1.002275  3.237001
# N163A    1.0     NaN    NaN     558.0     44.0  1.301930  -5.834012  4.476464
# N163C    1.0     NaN    NaN    4766.0    291.0 -1.801392  -4.521825  3.685828
# N163D    1.0     NaN    NaN     789.0     77.0       NaN  -5.295015  4.716370
# N163D    1.0     NaN    NaN     789.0     77.0 -1.241246  -5.295015  4.716370
# E164G    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# ...      ...     ...    ...       ...      ...       ...        ...       ...
# H379R    1.0     NaN    NaN     380.0     53.0       NaN  -7.086775  3.826712
# H379T    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# Q384R    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W399S    NaN     NaN    NaN       1.0      0.0       NaN        NaN       NaN
# W399R    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W399C    1.0     NaN    NaN      39.0      4.0       NaN  -6.681310  6.248931
# W399G    NaN     NaN    NaN       1.0      0.0       NaN        NaN       NaN
# W399C    1.0     NaN    NaN      39.0      4.0       NaN  -6.681310  6.248931
# W399S    NaN     NaN    NaN       1.0      0.0       NaN        NaN       NaN
# W399A    0.0     NaN    NaN      14.0      2.0       NaN       -inf  4.808142
# S400A    9.0     NaN    NaN  164795.0  11833.0  0.306895  -1.505160  3.165114
# D403A    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# N404A    1.0     NaN    NaN     393.0     18.0  2.505791  -6.393628  4.238567
# N404C    NaN     NaN    NaN       NaN      NaN  3.077961        NaN       NaN
# F405A    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# E406A    NaN     NaN    NaN       1.0      0.0  0.434310        NaN       NaN
# E406D    1.0     NaN    NaN    1146.0     94.0  1.054599  -4.116360  5.525909
# W407Q    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W407R    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W407G    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W407A    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W407Q    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# A408A    NaN     NaN    NaN       NaN      NaN  0.455931        NaN       NaN
# W409A    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# W409Y    NaN     NaN    NaN       NaN      NaN -2.885079        NaN       NaN
# K413A   33.0     NaN    NaN  285858.0  48589.0       NaN  -1.052490  3.067316
# F415A    1.0     NaN    NaN      80.0     20.0       NaN       -inf  4.806941
# F415N    NaN     NaN    NaN       NaN      NaN       NaN        NaN       NaN
# E423S   12.0  317.35  65.22   97777.0   6431.0 -0.040760  -1.309122  3.882802
# WT       NaN     NaN    NaN       NaN      NaN  0.455931        NaN       NaN
#
#        norm_kcatkm                  pos
# S14A     -2.500042                   14
# T15A           NaN                   15
# S16A     -3.761433                   16
# S16A     -3.761433                   16
# S16N           NaN                   16
# S17A     -2.330892                   17
# S17E     -1.686320                   17
# Y18A     -4.329679                   18
# Q19C    -13.066811                   19
# Q19A    -10.668915                   19
# Q19S    -10.501861                   19
# W34A           NaN                   34
# V52G     -1.735755                   52
# F72H           NaN                   72
# R76A           NaN                   76
# I91E     -1.322210                   91
# H101R    -1.556809                  101
# H119A    -3.909555                  119
# H119E          NaN                  119
# H119N    -8.660091                  119
# W120F    -2.780308                  120
# W120H    -6.217744                  120
# W120A   -13.066811                  120
# V147S    -6.507195                  147
# E154D    -0.621705                  154
# N163A    -6.742452                  163
# N163C    -4.597548                  163
# N163D    -6.396044                  163
# N163D    -6.396044                  163
# E164G          NaN                  164
# ...            ...                  ...
# H379R    -7.126639                  379
# H379T          NaN                  379
# Q384R          NaN                  384
# W399S   -13.066811                  399
# W399R          NaN                  399
# W399C    -9.403249                  399
# W399G   -13.066811                  399
# W399C    -9.403249                  399
# W399S   -13.066811                  399
# W399A   -10.427753                  399
# S400A    -1.054353                  400
# D403A          NaN                  403
# N404A    -7.093001                  404
# N404C          NaN                  404
# F405A          NaN                  405
# E406A   -13.066811                  406
# E406D    -6.022778                  406
# W407Q          NaN                  407
# W407R          NaN                  407
# W407G          NaN                  407
# W407A          NaN                  407
# W407Q          NaN                  407
# A408A          NaN                  408
# W409A          NaN                  409
# W409Y          NaN                  409
# K413A    -0.503560                  413
# F415A    -8.684784                  415
# F415N          NaN                  415
# E423S    -1.576366                  423
# WT             NaN  9221120237041090560
#
# [133 rows x 33 columns]

# %%
plt.figure( figsize=(18,36) ) 
plt.subplots_adjust(left=-11.8)
rc('axes', edgecolor='none')

font = { 'size': 14 }
rc('font', **font)

# recapitulate original heat map 

orig_cmap = mcolors.from_levels_and_colors(
    [0, 0.5, 1], 
    [(34,34,45,0.1), 'green']
)


# heat map columns 

plt.subplot( 1, 6, 1 )
plt.imshow( df[ ['norm_tm'] ], interpolation='none', cmap='bwr', origin='upper' ) 
plt.xticks( [ 0 ], [ '$T_m$' ], rotation='vertical' )
plt.yticks( range( len( df.index ) ), df.index )
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 2 )
plt.imshow( df[ ['protein_on_gel'] ], interpolation='none', cmap='Greys' ) 
plt.tick_params( length=0 ) 
plt.xticks( [ 0 ], [ 'SDS-PAGE' ], rotation='vertical' ); plt.yticks( [] ) 

plt.subplot( 1, 6, 3 )
plt.imshow( df[ ['norm_kcat'] ], interpolation='none', cmap='bwr' ) 
plt.xticks( [ 0 ], [ '$k_{cat}$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 4 )
plt.imshow( df[ ['norm_km'] ], interpolation='none', cmap='bwr' ) 
plt.xticks( [ 0 ], [ '$K_M$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

plt.subplot( 1, 6, 5 )
plt.imshow( df[ ['norm_kcatkm'] ], interpolation='none', cmap='bwr' ) 
plt.xticks( [ 0 ], [ '$k_{cat}/K_M$' ], rotation='vertical' ); plt.yticks( [] ) 
plt.tick_params( length=0 ) 

#plt.subplot( 1, 6, 6 )
#plt.scatter( 0, 0 ) 
#plt.xticks( [ 0 ], [ '$k_{cat}/K_M$' ], rotation='vertical' ); plt.yticks( [] ) 
#plt.tick_params( length=0 ) 

plt.tight_layout()
plt.savefig( 'fig2/plt_out.png', dpi=300 ) 
plt.show() 

#SS16A is duplictaed
#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
data= np.random.random((5, 4))
df = pd.DataFrame(data, index=Index, columns=Cols)

# Values from 0-0.5 will be red and 0.5-1 will be green
cmap, norm = mcolors.from_levels_and_colors([0, 0.5, 1], [(.0,.34,0.8,0.1), 'green'])

plt.pcolor(df, cmap=cmap, norm=norm)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.show()

# %%
# structure-stability?

# machine learning predictions?

# conservation analysis?

# %%
# descriptive statistics for paper 

import pandas

df = pandas.read_csv( 'data/clean/production.csv', index_col='mutant' )
df['pos'] = df.index.str[1:-1].astype( int )

df.describe()
# Out:
#               idx    colonies  grow_weight  expr_weight       beads  \
# count  132.000000  118.000000   117.000000   118.000000  118.000000
# mean    71.803030   35.694915   255.482051   395.923729    0.279661
# std     40.534678   34.926420    94.798105   122.243917    0.450747
# min      1.000000    1.000000    57.000000   154.000000    0.000000
# 25%     40.750000    7.250000   190.000000   306.000000    0.000000
# 50%     73.500000   25.000000   258.000000   388.000000    0.000000
# 75%    106.250000   54.750000   311.000000   498.250000    1.000000
# max    139.000000  150.000000   515.000000   722.000000    1.000000
#
#                 y      norm_y  gel_img_exists  protein_on_gel  \
# count  118.000000  118.000000             118      118.000000
# mean     0.396441    0.480000               1        0.762712
# std      0.330104    0.366527               0        0.368131
# min      0.064000    0.060000               1        0.000000
# 25%      0.184750    0.220000               1        0.500000
# 50%      0.287000    0.370000               1        1.000000
# 75%      0.484250    0.627500               1        1.000000
# max      1.831000    1.830000               1        1.000000
#
#        assay_data_exists   tm_exists  in_plos_paper         tm          k  \
# count                118  118.000000     118.000000  65.000000  65.000000
# mean                   1    0.576271       0.813559  39.157182  -0.785054
# std                    0    0.496256       0.391123   1.508533   0.377742
# min                    1    0.000000       0.000000  34.708312  -1.703773
# 25%                    1    0.000000       1.000000  38.471567  -1.005693
# 50%                    1    1.000000       1.000000  39.421645  -0.688686
# 75%                    1    1.000000       1.000000  39.955931  -0.480827
# max                    1    1.000000       1.000000  42.577961  -0.172265
#
#                 pos
# count  1.330000e+02
# mean   3.298487e+07
# std    3.803972e+08
# min    1.400000e+01
# 25%    1.670000e+02
# 50%    2.930000e+02
# 75%    3.570000e+02
# max    4.386955e+09
